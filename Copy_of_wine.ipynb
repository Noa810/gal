# %% [markdown]
# <a href="https://colab.research.google.com/github/Noa810/gal/blob/main/Copy_of_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><big><big><big><big>Wine Quality</h1>
# <img src="https://storage.googleapis.com/kaggle-datasets-images/1866301/3047725/a8442c4170479f83d6dcab16b655bf87/dataset-cover.jpg?t=2022-01-15-19-25-24">
#
# <div dir="rtl">
# מגישה: נעה בן דוד<br>
# בית ספר:מדעים<br>
# תעודת זהות: 0218512291
# <br>
# מורה: מיכל מנדל
# <br>
# תאריך הגשה: יוני 2025
#
# קישור עריכה למצגת:
#
# https://1drv.ms/p/c/3ecc7fa86ee2ee7f/Ec-lpFvuq0NLlMwWeS-IjM4BSqt3zh3VSXBEHvH5YO__ag

# %% [markdown]
# <div dir="rtl">
# קישור לdataset מקאגל-
# <br>
#
#
#
# https://www.kaggle.com/datasets/yasserh/wine-quality-dataset
#
# <h1> מידע על מאגר הנתונים(מקאגל)- </h1>
# <br>
#
# מערך הנתונים הזה קשור לגרסאות אדומות של היין הפורטוגזי "Vinho Verde". מערך הנתונים מתאר את כמות הכימיקלים השונים הקיימים ביין ואת השפעתם על איכותו. ניתן לראות את מערכי הנתונים כמשימות סיווג או רגרסיה. השיעורים מסודרים ולא מאוזנים (למשל, יש הרבה יותר יינות רגילים מאשר מעולים או גרועים). המשימה שלך היא לחזות את איכות היין באמצעות הנתונים הנתונים.
#
# פרויקט פשוט אך מאתגר, לצפות את איכות היין.
# המורכבות נובעת מהעובדה שלמערך הנתונים יש פחות דוגמאות, והוא מאוד לא מאוזן.
# האם אתה יכול להתגבר על המכשולים האלה ולבנות מודל חיזוי טוב כדי לסווג אותם?

# %% [markdown]
# <div dir="rtl">
#
# # **<big><big><big>-המחקר שלי**
#
# מטרת המחקר שלי היא לגלות מה הופך יין ליין איכותי ומה המאפיינים המרכזים של יין שכזה, את מטרת המחקר אממש בסוף חלק הknn.

# %%
import pandas as pd
#ספריית פנדה לייבוא הנתונים ולהצגה שלהם בדרכים שונות
import seaborn as sns
# ספריית סיבורן בשביל גרפים
import matplotlib.pyplot as plt
#ספריית מאטפלוט בשביל גרפים
import numpy as np
#ספריית נאמפאי בשביל לחלק נתונים בחלק הקננ
# !pip install scikit-learn
from sklearn.pipeline import Pipeline

from sklearn.neighbors import KNeighborsRegressor
# קייינייבורסרגרסור על מנט ליצור מודל חיזוי
from sklearn.model_selection import GridSearchCV
# גרידסרצ בשביל אימון וחיזוי הנתונים
from sklearn.model_selection import train_test_split
# טריין טסט ספליט על מנת לחלק את הנתונים בין נתוני אימון לנתוני בחינה
from sklearn.metrics import accuracy_score
# אקקורסי סקור על מנט למדוד את רמת הדיוק של החיזוי
from sklearn.linear_model import LinearRegression
# לינאר רגרסיון על מנת לבדוק קשר בין ערכין למטרת החיזוי
from sklearn.preprocessing import StandardScaler
# סטאנדרט סקלר על מנט נרמול הנתונים
from sklearn.metrics import confusion_matrix , classification_report ,ConfusionMatrixDisplay
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)

# %% [markdown]
# # **ייבוא מאגר הנתונים**

# %%
df = pd.read_csv('/content/WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             6.7             0.580         0.08             1.8      0.097
# 10            5.6             0.615         0.00             1.6      0.089
# 11            7.8             0.610         0.29             1.6      0.114
# 12            8.5             0.280         0.56             1.8      0.092
# 13            7.9             0.320         0.51             1.8      0.341
# 14            7.6             0.390         0.31             2.3      0.082
# 15            7.9             0.430         0.21             1.6      0.106
# 16            8.5             0.490         0.11             2.3      0.084
# 17            6.9             0.400         0.14             2.4      0.085
# 18            6.3             0.390         0.16             1.4      0.080
# 19            7.6             0.410         0.24             1.8      0.080
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  15.0                  65.0   0.9959  3.28       0.54
# 10                 16.0                  59.0   0.9943  3.58       0.52
# 11                  9.0                  29.0   0.9974  3.26       1.56
# 12                 35.0                 103.0   0.9969  3.30       0.75
# 13                 17.0                  56.0   0.9969  3.04       1.08
# 14                 23.0                  71.0   0.9982  3.52       0.65
# 15                 10.0                  37.0   0.9966  3.17       0.91
# 16                  9.0                  67.0   0.9968  3.17       0.53
# 17                 21.0                  40.0   0.9968  3.43       0.63
# 18                 11.0                  23.0   0.9955  3.34       0.56
# 19                  4.0                  11.0   0.9962  3.28       0.59
#
#     alcohol  quality  Id
# 0       9.4        5   0
# 1       9.8        5   1
# 2       9.8        5   2
# 3       9.8        6   3
# 4       9.4        5   4
# 5       9.4        5   5
# 6       9.4        5   6
# 7      10.0        7   7
# 8       9.5        7   8
# 9       9.2        5  10
# 10      9.9        5  12
# 11      9.1        5  13
# 12     10.5        7  16
# 13      9.2        6  19
# 14      9.7        5  21
# 15      9.5        5  22
# 16      9.4        5  23
# 17      9.7        6  24
# 18      9.3        5  25
# 19      9.5        5  26

# %% [markdown]
# # **פעולת info**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# <div dir="rtl">
#
# **העמודות:**
#
# משתני קלט (מבוסס על מבחנים פיזיקוכימיים):\
# 1 - חומציות קבועה , משתנה ממשי ורציף\
# 2 - חומציות נדיפה,משתנה ממשי ורציף\
# 3 - חומצת לימון,משתנה ממשי ורציף\
# 4 - שאריות סוכר,משתנה ממשי ורציף\
# 5 - כלורידים,משתנה ממשי ורציף\
# 6 - דו תחמוצת גופרית חופשית,משתנה ממשי ורציף\
# 7 - סך דו תחמוצת הגופרית,משתנה ממשי ורציף\
# 8 - צפיפות,משתנה ממשי ורציף\
# 9 - pH,משתנה ממשי ורציף\
# 10 - סולפטים,משתנה ממשי ורציף\
# 11 - אלכוהול,משתנה שלם ורציף\
# משתנה פלט (מבוסס על נתונים תחושתיים):\
# 12 - איכות (ציון בין 0 ל-10),משתנה שלם ורציף

# %% [markdown]
# # **הורדת נתונים חסרים\עמודות לא רצויות**

# %%
# בדיקה האם יש ערכים חסרים בעזרת הפעולה dropna
# ניתן להבין שאין משתנים חסרים מכיוון שיש אותו מספר שורות גם לפני ביצוע הפעולה
df.dropna(axis=0)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4        5     0
# 1         9.8        5     1
# 2         9.8        5     2
# 3         9.8        6     3
# 4         9.4        5     4
# ...       ...      ...   ...
# 1138     11.0        6  1592
# 1139      9.5        6  1593
# 1140     10.5        5  1594
# 1141     11.2        6  1595
# 1142     10.2        5  1597
#
# [1143 rows x 13 columns]

# %%
df.drop('Id', axis=1, inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1138     11.0        6
# 1139      9.5        6
# 1140     10.5        5
# 1141     11.2        6
# 1142     10.2        5
#
# [1143 rows x 12 columns]

# %% [markdown]
# <div dir="rtl">
# הורדתי את העמודה Id מכיוון שהיא לא קשורה לנתונים ואין צורך להשאיר אותה במידע ולהכליל בגרפים

# %% [markdown]
# # **פעולת columns**

# %%
#בדיקת שמות העמודות
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %% [markdown]
# הפעולה מחזירה את השמות של כל העמודות במאגר הנתונים

# %% [markdown]
# # **פעולת nunique**

# %%
df.nunique()
# Out:
# fixed acidity            91
# volatile acidity        135
# citric acid              77
# residual sugar           80
# chlorides               131
# free sulfur dioxide      53
# total sulfur dioxide    138
# density                 388
# pH                       87
# sulphates                89
# alcohol                  61
# quality                   6
# dtype: int64

# %% [markdown]
# <div dir="rtl">
# פעולה המחזירה את כמות המשתנים שמופיעים לפחות פעם אחת בכל עמודה , למשל בעמודה של הquality אפשר לדעת שנפגוש 6 אופציות לדירוג

# %%
df.select_dtypes(include="object").nunique()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# <div dir="rtl">
# פעולה המחזירה את כל המשתנים המופיעים לפחות פעם אחת בכל עמודה מסוג object,
# מכיוון שאין במאגר נתונים עמודה מסוג object בטבלא אין ערכים

# %% [markdown]
# # **פעולת describe**

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.205000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# <div dir="rtl">
#
# פעולה המציגה נתונים סטטיסטיים על משתנים מסוג מספרי מה שיכול לעזור בבניית גרף.
#
#
# **count** מייצג כמה פעמים יש במאגר הנתונים שלנו שורה שבה הערך נמצא, אפשר לראות
# שבכל המשתנים count = 1143, זה מכיוון שאין נתונים חסרים.
#
# **mean** מייצג את הממוצע של הערכים בעמודה
#
# **std** מייצג את סטיית התקן של הערכים בעמודה
#
#
# **min** הערך הכי קטן שמופיע בעמודה
#
# **25%** מייצגת את הערך אשר גדול מ25% משאר הערכים בעמודה
#
# **50%** מייצגת את הערך אשר גדול מ50% משאר הערכים בעמודה, החציון
#
# **75%** מייצגת את הערך אשר גדול מ75% משאר הערכים בעמודה
#
# **max** מייצגת את הערך הכי גדול בעמודה

# %% [markdown]
# # **ויזואליזציה**

# %% [markdown]
# **<h1> פעולת corr וheatmap </h1>**

# %%
numerical_df = df.select_dtypes(include=['number'])
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.171831   0.107889            -0.164831
# volatile acidity           -0.005751   0.056336            -0.001962
# citric acid                 0.175815   0.245312            -0.057589
# residual sugar              1.000000   0.070863             0.165339
# chlorides                   0.070863   1.000000             0.015280
# free sulfur dioxide         0.165339   0.015280             1.000000
# total sulfur dioxide        0.190790   0.048163             0.661093
# density                     0.380147   0.208901            -0.054150
# pH                         -0.116959  -0.277759             0.072804
# sulphates                   0.017475   0.374784             0.034445
# alcohol                     0.058421  -0.229917            -0.047095
# quality                     0.022002  -0.124085            -0.063260
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.110628  0.681501 -0.685163   0.174592
# volatile acidity                  0.077748  0.016512  0.221492  -0.276079
# citric acid                       0.036871  0.375243 -0.546339   0.331232
# residual sugar                    0.190790  0.380147 -0.116959   0.017475
# chlorides                         0.048163  0.208901 -0.277759   0.374784
# free sulfur dioxide               0.661093 -0.054150  0.072804   0.034445
# total sulfur dioxide              1.000000  0.050175 -0.059126   0.026894
# density                           0.050175  1.000000 -0.352775   0.143139
# pH                               -0.059126 -0.352775  1.000000  -0.185499
# sulphates                         0.026894  0.143139 -0.185499   1.000000
# alcohol                          -0.188165 -0.494727  0.225322   0.094421
# quality                          -0.183339 -0.175208 -0.052453   0.257710
#
#                        alcohol   quality
# fixed acidity        -0.075055  0.121970
# volatile acidity     -0.203909 -0.407394
# citric acid           0.106250  0.240821
# residual sugar        0.058421  0.022002
# chlorides            -0.229917 -0.124085
# free sulfur dioxide  -0.047095 -0.063260
# total sulfur dioxide -0.188165 -0.183339
# density              -0.494727 -0.175208
# pH                    0.225322 -0.052453
# sulphates             0.094421  0.257710
# alcohol               1.000000  0.484866
# quality               0.484866  1.000000

# %% [markdown]
# <div dir="rtl">
# הפקודה corr מראה את הקשר הלינארי בין 2 ערכים מספריים.
# לדוגמא אם בין quality וalcohol יצא 0.48 אזאפשר לדעת שככל שאחד מהם עולה גם השני עולה בהתאמה של כמעט חצי מהעלייה.
# ככל שהקשר קרוב יותר ל-1 או ל1 אפשר להבין שהמשתנים משפיעים אחד על השני

# %%
#1
# אני שומרת את הפקודה corr בתור משתנה בשביל ליצור heatmap
corr_matrix = df.corr(numeric_only=True)

plt.figure(figsize=(10,8))
plt.title('Correlation Matrix Heatmap')

ax = sns.heatmap(corr_matrix, annot=True)

# %% [markdown]
# <div dir="rtl">
# הפעולה heatmap מראה את הפעולה corr בצורה חזותית , היא עדיין מייצגת לנו את
# אותם ערכים כמו בפעולה corr אך נוח יותר להסתכל על זה בין היתר מכיוון שהצבעים המודגשים עוזרים לנו לראות ערכים עם קשר גבוה

# %% [markdown]
# **<h1> גרף jointplot </h1>**

# %%
#2
sns.jointplot(x='alcohol', y='density', data=df, kind='reg')
plt.show()

# %% [markdown]
# <div dir="rtl">
#
# השתמשתי בגרף jointplot,
#  הגרף מתבצע על המשתנים alcohol(רציף) ועל density (רציף)
#
# הגרף מראה את הקשר הלינארי בין 2 המשתנים.
#
# <h1> מסקנות: </h1>
#
# - ניתן לראות שיש אזור הדחוס בנתונים כאשר רוב הנקודות נמצאות באזורו
#
# - קו המגמה עובר קרוב לרוב הנקודות
#
# - קו המגמה יורד
#
#
#
# **סיכום:**
#
# אפשר להסיק שככל שכמות האלכוהול עולה כמות הדחיסות יורדת , בheatmap ניתן היה לראות שהקשר בין alcohol לבין density הוא -0.49 אז אפשר לדעת שהם משפיעים אחד על השני

# %% [markdown]
# **<h1> גרף scatterplot </h1>**

# %%
#3
plt.figure(figsize=(10,10))
sns.scatterplot(x = df['fixed acidity'] , y = df['density'])
plt.show()

# %% [markdown]
# <div dir="rtl">
#
# השתמשתי בגרף פיזור על המשתנים fixed acidity (רציף) ועל density (רציף)
#
# <h1> מסקנות: </h1>
#
# - אפשר לראות שיש אזור שבאיזורו ממוקמות רוב הנקודות
#
# - לא צריך קו מגמה כדי לראות שיש אכן קשר בין שני הערכים
#
# - כמעט ואין ערכים היוצאים מן הכלל ולא קרובים לשאר הנקודות
#
#
#
# **סיכום:**
#
# בheatmap הקשר בין 2 המשתנים הוא 0.68, כמו שניתן לראות בגרף הזה באמת ככל שאחד המשתנים עולה כך גם משנהו

# %% [markdown]
# **<h1> גרף jointplot</h1>**

# %%
#4
sns.jointplot(x='fixed acidity', y='alcohol', data=df, kind='reg')
plt.show()

# %% [markdown]
# <did dir="rtl">
#
# גרף jointplot,
#
# הגרף מתבצע על fixed acidity וalcohol
#
# <h1>מסקנות:</h1>
#
# - אפשר לראות שאין כל כך קשר בין 2 הערכים
#
# - קו המגמה בעל שיפוע קרוב ל0
#
# - הנקודות מפוזרות בצורה לא מסודרת
#
#
# **סיכום:**
#
# כפי שהיה ניתן להבין מהheatmap , הקשר בין 2 הערכים קטן(-0.075) , למרות ש2 הערכים בעלי קשר גבוהה לערך density

# %% [markdown]
# **<h1> גרף histplot</h1>**

# %%
#5
plt.figure(figsize=(10,10))
sns.histplot(x = df['alcohol'] , y = df['quality'])
plt.show()

# %% [markdown]
# <div dir="rtl">
#
# השתמשתי בגרף histplot
# על המשתנים alcohol(רציף) ועל quality (רציף)
#
#
# <h1> מסקנות: </h1>
#
#
# - דירוג רוב האלכוהול  נמצא בטווח 5-7 כאשר הריכוז הכי גבוהה בדירוג 5
#
# - ככל שעולים בדירוג ניתן לראות שאורך טווח הארכים נוטה לזוז ימינה
#
#
#
# **סיכום:**
#
#
# בheatmap הקשר בין 2 הערכים הוא 0.48 , בגרף קשה יותר לראות את הקשר אך בהחלט ניתן לראות את השינוי שמתבצע ככל שעולים, כך הטווח זז ימינה מה שאומר שאחוז האלכוהול עולה וכך גם איכות היין.

# %% [markdown]
# **<h1>גרף histplot </h1>**

# %%
#6
plt.figure(figsize=(10,6))
sns.histplot(data=df,x='alcohol',hue='quality',palette='Paired',kde=True)
plt.show()

# %% [markdown]
# <div dir="rtl">
#
# השתמשתי בגרף עמודות עם קווי מגמה לכל ערך, למשל לערך quality=5 יש זינוק בין 9-10, הערך בצבע ירוק בהיר ואפשר לראות שגם קו המגמה שלו באותו הצבע ועולה כאשר הערך עולה.
#
# הגרף מתבצע על הערכים alcohol(רציף) ועל quality (רציף)
#
# <h1> מסקנות: </h1>
#
# - אפשר לראות שרוב הנתונים הם על quality הנעה בין 5-7, כאשר 7-8 ו3-4 נמצאים בתחתית וכמעט לא מופיעים כי כמעט אין נקודות המכילות את הערכים הללו
#
# - ישנו זינוק בין הערכים 9-10
#
# - הערכים 7-8 מופיעים מימין יותר כאשר הנקודה הכי גבוהה של קו המגמה של quality=7 בנצא בין 12-13
#
#
#
# **סיכום:**
#
# הגרף מייצג בצורה שונה את מה שכבר הבנו בגרף לפניו

# %% [markdown]
# # <h1><big><big><big><big><big><big><big><big>KNN</big></big></big></big></big></big></big></big></h1>

# %% [markdown]
# # **<h1> הכנה של הנתונים בהם אשתמש בלימוד המכונה</h1>**

# %%
# הכנה של הערכים ללימוד המכונה
x = df.drop(['residual sugar'],axis=1).to_numpy()
x.shape
# Out:
# (1143, 11)

# %% [markdown]
# <div dir="rtl">
# הוצאה של העמודה residual sugar מכיוון שהיא הייתה בעלת הקשר הקרוב ביותר ל0 בheatmap בינה לבין quality (מכיוון שאני רוצה למדוד את האיכות)

# %%
# הכנה של ערך העמודה האופקית, אשר אני רוצה למדוד, שזהו איכות היין
y = df['quality'].to_numpy()
y.shape
# Out:
# (1143,)

# %% [markdown]
# # **<h1> אימון הנתונים</h1>**

# %%
#שליחת הנתונים לאימון ובדיקה
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,\
                                               shuffle=True,random_state=100)

print("train: ",X_train.shape,y_train.shape)

print("test: ",X_test.shape,y_test.shape)
# Out:
# train:  (914, 11) (914,)
# test:  (229, 11) (229,)

# %% [markdown]
# # **<h1> נרמול הנתונים</h1>**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("min: {} max: {}".format(X_train.min(),X_train.max()))
print("min: {} max: {}".format(X_test.min(),X_test.max()))

#נרמול נתונים בשיטת minmax
# Out:
# min: 0.0 max: 1.0
# min: 0.0 max: 1.160714285714286

# %%
# אפשרות שניה לנרמול בשיטה סטנדרטית
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # **<h1> הכנסה למודל</h1>**

# %%
pipe = Pipeline([
        ('scale', StandardScaler()),
        # הוא הופך את הנתונים כך שהממוצע שלהם יהיה 0 וסטיית התקן תהיה 1.
        ('knn', KNeighborsRegressor())
        # העברת הנתונים למודל לאחר נרמול
        ])


param_grid = {
    'knn__n_neighbors' :[k for k in range(1,700,20)]
}

# %%
knn_clf = GridSearchCV(pipe, param_grid=param_grid, cv=5, verbose=1)

knn_clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('knn', KNeighborsRegressor())]),
#              param_grid={'knn__n_neighbors': [1, 21, 41, 61, 81, 101, 121, 141,
#                                               161, 181, 201, 221, 241, 261, 281,
#                                               301, 321, 341, 361, 381, 401, 421,
#                                               441, 461, 481, 501, 521, 541, 561,
#                                               581, ...]},
#              verbose=1)

# %% [markdown]
# pipe - המודל
#
# param_grid - מגדיר את רשת הפרמטים לחיפוש
#
#
# cv - מספר החלוקות, כל חלק יתבצע פעם אחת
#  כאשר 4 החלקים האחרים ישמשו כנתוני אימון , הציון הסופי הוא ממוצע כל החלקים
#
#  verdose- כמה מידע יודפס במהלך התהליך

# %%
#14
cv_results = pd.DataFrame(knn_clf.cv_results_)
print(cv_results[['param_knn__n_neighbors','mean_test_score','rank_test_score']].sort_values('rank_test_score'))
# Out:
#     param_knn__n_neighbors  mean_test_score  rank_test_score
# 0                        1         0.853993                1
# 1                       21         0.796335                2
# 2                       41         0.753887                3
# 3                       61         0.724890                4
# 4                       81         0.698850                5
# 5                      101         0.673015                6
# 6                      121         0.644633                7
# 7                      141         0.617994                8
# 8                      161         0.594410                9
# 9                      181         0.572735               10
# 10                     201         0.549737               11
# 11                     221         0.529822               12
# 12                     241         0.510927               13
# 13                     261         0.491731               14
# 14                     281         0.472530               15
# 15                     301         0.453539               16
# 16                     321         0.435031               17
# 17                     341         0.415765               18
# 18                     361         0.397249               19
# 19                     381         0.378178               20
# 20                     401         0.359163               21
# 21                     421         0.341028               22
# 22                     441         0.322084               23
# 23                     461         0.302555               24
# 24                     481         0.283889               25
# 25                     501         0.263912               26
# 26                     521         0.244346               27
# 27                     541         0.223040               28
# 28                     561         0.200521               29
# 29                     581         0.177827               30
# 30                     601         0.155414               31
# 31                     621         0.131846               32
# 32                     641         0.109086               33
# 33                     661         0.084908               34
# 34                     681         0.057911               35

# %%
# מוצא את ערך החיזוי הכי קרוב למציאות ומדפיס אותו, ערך חיזוי של 1 אומר שזה חזה במדוייק
best_k = knn_clf.best_params_['knn__n_neighbors']
print("The best k is: ",best_k)

# מבטיח שהערך שמצאנו בשורת הקוד הקודמת יהיה במודל החדש הנשמר במשתנה
#Knn1
Knn1 = KNeighborsRegressor(n_neighbors=best_k)
Knn1.fit(X_train,y_train)
# Out:
# The best k is:  1
# KNeighborsRegressor(n_neighbors=1)

# %%
# מקבל את הנתונים לבדיקה ומנסה לחזות אותם, אני שומרת את החיזוי בתור משתנה בשביל להציג לאחר מכן
y_pred = Knn1.predict(X_test)
y_pred.shape
# Out:
# (229,)

# %% [markdown]
# <div dir="rtl">
#
#
#
# # **<h1> Confusion matrix & Classification report </h1>**

# %%
#הגדרה של גודל התצוגה
fig,ax = plt.subplots(figsize=(10,10))
# להראות את התצוגה של הערכים שחיזינו מול הערכים האמיתיים
confusion_matrix= ConfusionMatrixDisplay.from_predictions(y_test,y_pred,ax=ax)
# מדפיס את הקשר הלינארי בין ערכים שונים
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.60      0.38      0.46         8
#            5       0.93      0.98      0.95       102
#            6       0.97      0.96      0.96        97
#            7       0.95      0.86      0.90        22
#
#     accuracy                           0.94       229
#    macro avg       0.86      0.79      0.82       229
# weighted avg       0.93      0.94      0.94       229

# %% [markdown]
# <div dir="rtl">
#
# יצירת גרף של חיזוי מול תוצאה אמיתית, אפשר לראות שרוב הנתונים חוזו בצורה נכונה חוץ ממספר נתונים בודדים שחוזו נקודה למעלה או למטה , במבט מלמעלה זה אומר שהחיזוי הצליח
#
#
# **Precision (דיוק)**
#
# מה אחוז הדגימות שהמודל סיווג כמשתייכות למחלקה מסוימת, ואכן השתייכו למחלקה זו בפועל.
#
#
# **Recall (רגישות / כיסוי)**
#
# מה אחוז הדגימות שבאמת משתייכות למחלקה מסוימת, שהמודל סיווג נכון.
#
#
# **F1-Score**
#
#
# ממוצע הרמוני של Precision ו-Recall. הוא מספק איזון בין שני המדדים ולעיתים קרובות שימושי יותר מאשר Precision או Recall לבד, במיוחד כשיש אי-איזון במחלקות.
#
# **Support (תמיכה)**
#
# מספר הדגימות האמיתיות (ב-y_true) השייכות למחלקה זו בנתוני הבדיקה.

# %%
knn3 = KNeighborsRegressor(n_neighbors=1)
knn3.fit(x,y)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %% [markdown]
# <div dir="rtl">
#
#  מודל רגרסיה משמש לחיזוי ערכים רציפים (בניגוד למודל סיווג שמחזה מחלקות). במקרה זה, המטרה היא לחזות את איכות היין, שהיא ערך מספרי רציף.
#
#  n_neighbors מייצג את מספר השכנים הקרובים ביותר לנקודה שממנו יחזה את שיעור איכות היין

# %% [markdown]
# # **<h1>ACCURACY SCORE & PREDICTION</h1>**

# %% [markdown]
# <div dir="rtl">
#
# כדי לבדוק האם יש גורם אחד ספציפי שמשפיע על איכות היין אקח את 3 המשתנים הכי רחוקים מ0 בquality במפת הheatmap ואנסה לשנות אותם בכל חיזוי.

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             21.000000     0.995570
# 50%       0.079000            13.000000             37.000000     0.996680
# 75%       0.090000            21.000000             61.000000     0.997845
# max       0.611000            68.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1143.000000  1143.000000  1143.000000  1143.000000
# mean      3.311015     0.657708    10.442111     5.657043
# std       0.156664     0.170399     1.082196     0.805824
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.205000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# דוגמא לחיזוי נתונים, אני מכניסה ערכים לכל עמודה ומקבלת את הדירוג שאמור לצאת לאיכות היין

knn3.predict([[7.9,0.52,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0.62,10.2]])
# Out:
# array([8.])

# %%
#alcohol
knn3.predict([[7.9,0.52,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0.62,8]])
# Out:
# array([5.])

# %%
#-volatile acidity
knn3.predict([[7.9,1.5,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0.62,10.2]])
# Out:
# array([8.])

# %%
#sulphates
knn3.predict([[7.9,0.52,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0,10.2]])
# Out:
# array([8.])

# %%
#שינוי שלושת הנתונים
knn3.predict([[7.9,1.5,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0,8]])
# Out:
# array([5.])

# %%
#שינוי כל הנתונים
knn3.predict([[7.1,0.39,0.09,1.9,0.07,7.0,21.0,0.9955,3.2,0.55,9.5]])
# Out:
# array([6.])

# %%
# דוגמא מהמאגר, אכן החיזוי כמו הערך שיש במאגר, שורה 3
knn3.predict([[11.2,0.28,0.56,1.9,0.075,17.0,60.0,0.9980,3.16,0.58,9.8]])
# Out:
# array([6.])

# %%
accuracy_score(y_true=y_test, y_pred = y_pred)
# Out:
# 0.9388646288209607

# %%
print(accuracy_score(y_true=y_test, y_pred = y_pred)*100)
# Out:
# 93.88646288209607

# %% [markdown]
# <div dir="rtl">
#
#
# למרות שהחיזוי עומד על אחוז גבוהה עדיין ההשפעה היחידה הייתה כאשר שיניתי את ערך האלכוהול וכאשר שיניתי את כל הערכים. בנוסף השתמשתי גם בשורה מן המאגר, הערך שחוזה היה שווה לערך שאכן בטבלא.

# %% [markdown]
# # **<big><big><big><big>SVM</big></big></big></big>**
# <div dir="rtl">
#
#  SVM משתמש במטוס החלטה (hyperplane) כדי להפריד בין קבוצות שונות של נתונים. המטרה היא למצוא את המטוס שמפריד בצורה הטובה ביותר בין הקבוצות, כך שהמרחק בין המטוס לבין הנקודות הקרובות ביותר מכל קבוצה (נקראות "תמכויות סבירות" או support vectors) יהיה מקסימלי.
#
#
#   SVM מצריך אימון מוקדם ומספק פתרון מדויק יותר לעיתים קרובות, בעוד KNN הוא פשוט וקל, אך עשוי להיות פחות יעיל בבעיות מסוימות.

# %%
x = df.drop(['residual sugar'],axis=1).to_numpy()
y = df['quality']

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,\
                                      shuffle=True,random_state=41)
print("train: ", X_train.shape, y_train.shape)
print("test:  " , X_test.shape, y_test.shape)
# Out:
# train:  (914, 11) (914,)
# test:   (229, 11) (229,)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("min: {} max: {}".format(X_train.min(),X_train.max()))
print("min: {} max: {}".format(X_test.min(),X_test.max()))

#נרמול נתונים בשיטת minmax
# Out:
# min: 0.0 max: 1.0000000000000002
# min: -0.043678160919526476 max: 1.0404411764705883

# %%
from sklearn.svm import SVC

pipe = Pipeline([
        ('scale', MinMaxScaler()),
        ('svc', SVC())
        ])

# %%
param_grid = {
    'svc__kernel': ['linear','rbf','poly'],
    'svc__C' :[0.1,1,10,15]
}
param_grid
# Out:
# {'svc__kernel': ['linear', 'rbf', 'poly'], 'svc__C': [0.1, 1, 10, 15]}

# %%
svm_clf_1 = GridSearchCV(pipe, param_grid=param_grid, cv=4, verbose=1)
svm_clf_1.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 12 candidates, totalling 48 fits
# GridSearchCV(cv=4,
#              estimator=Pipeline(steps=[('scale', MinMaxScaler()),
#                                        ('svc', SVC())]),
#              param_grid={'svc__C': [0.1, 1, 10, 15],
#                          'svc__kernel': ['linear', 'rbf', 'poly']},
#              verbose=1)

# %%
cv_results = pd.DataFrame(svm_clf_1.cv_results_)
cv_results[['param_svc__C','param_svc__kernel','mean_test_score','rank_test_score']].sort_values('rank_test_score')
# Out:
#     param_svc__C param_svc__kernel  mean_test_score  rank_test_score
# 5            1.0              poly         0.997807                1
# 11          15.0              poly         0.997807                1
# 9           15.0            linear         0.997807                1
# 8           10.0              poly         0.997807                1
# 6           10.0            linear         0.995624                5
# 2            0.1              poly         0.994532                6
# 10          15.0               rbf         0.984678                7
# 7           10.0               rbf         0.984678                7
# 4            1.0               rbf         0.973742                9
# 3            1.0            linear         0.948580               10
# 1            0.1               rbf         0.844638               11
# 0            0.1            linear         0.793223               12

# %%
svm_clf_1.best_params_
# Out:
# {'svc__C': 1, 'svc__kernel': 'poly'}

# %%
y_pred = svm_clf_1.predict(X_test)
y_pred.shape
# Out:
# (229,)

# %%
accuracy_score(y_true=y_test, y_pred = y_pred)
# Out:
# 1.0

# %%
fig, ax = plt.subplots(figsize=(3, 3))
ConfusionMatrixDisplay.from_predictions(y_true=y_test,y_pred = y_pred,\
                                values_format="d",cmap="Blues",ax=ax);

# %%
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00        90
#            6       1.00      1.00      1.00       103
#            7       1.00      1.00      1.00        28
#            8       1.00      1.00      1.00         2
#
#     accuracy                           1.00       229
#    macro avg       1.00      1.00      1.00       229
# weighted avg       1.00      1.00      1.00       229

# %%
multiple_new_data = np.array([
[7.9,0.320,0.51,1.8,0.341,17.0,56.0,0.9969,3.04,1.08,9.2],
[11.2,0.28,0.56,1.9,0.075,17.0,60.0,0.9980,3.16,0.58,9.8]
])
svm_predictions_multiple = svm_clf_1.predict(multiple_new_data)
print("SVM predictions for multiple samples:", svm_predictions_multiple)
# Out:
# SVM predictions for multiple samples: [5 5]

# %% [markdown]
# #<big><big><big>  סיכום ורפלקציה

# %% [markdown]
# <div dir="rtl">
#
# **סיכום ומסקנות:**
#
# knn;
#
# במהלך סיום הknn הופתעתי לדעת שחוץ מalcohol שאר המשתנים המובילים הרחוקים מ0 בטבלאת הheatmap
# עם quality, אינם משפיעים ישירות בהכרח על תוצר איכות היין
# יכול להיות שזה מכיוון שיכולת החיזוי אינה הייתה גבוהה מספיק אך נראה שאין גורם ספציפי חוץ מalcohol אשר משפיע ישירות על איכות היין, רק שינוי גורף של כל המשתנים.
# אפשר להגיד שבמטרת המחקר שלי לא קיבלתי את התוצאה לה ציפיתי((ציפיתי שעוד משתנים יוכלו לשנות את איכות היין)
#
#
# svm;
#
# תוצאת החיזוי שלי בsvm יצאה יותר גבוהה אך עדיין לא חיזה במדוייק את איכות היין, מה שמצביע על כך שאולי אין לי מספיק נתונים. אך, לא מצאתי עוד מאגר נתונים עם אותם הערכים.
#
# **רפלקציה:**
#
# במהלך העבודה נחפשתי לסביבת לימודים חדשה, אשר שונה מאוד מהתוכנות הרגילות שאני משתמשת בהן (בעיקר java וpython)
# מה שנתן לי ידע נרחב יותר על עולם התכנות ומקומות בהם אני יכולה למצוא מידע ועזרה.
# העבודה בסביבה שבה הקוד אינו רצוף הייתה אכן מאתגרת אך גם חדשה ומעניינת לחקירה.
#
# בתחילת העבודה פעלתי בדרך אחת לפי מה שלמדנו, אך לאחר שצברתי כלים מצאתי דרכים שונות לייצוג מידע .
#
#
# בתקלתי גם במגוון פקודות שלא הכרתי במהלך הלמידה העצמית, חלקן מאוד מעניינות ,חלקן פשוטות וחלקן מורכבות. עברתי גם על מגוון של datasets במטרה למצוא אחד
# עם נתונים מתאימים למחקר שלי, מה שגרם לי ללמוד לזהות מאפיינים שונים (לדוגמא
# חיפשתי מאגר מידע שהנתונים שלו בheatmap אינם כולם קטנים מ0.1 על מנת שהחיזוי יהיה מדוייק).
#
# במהלך העבודה החלפתי מספר פעמים את כל מאגרי הנתונים  עד שהגעתי למאגר שאני שלמה איתו ומרגישה שהצלחתי להעביר דרכו את הידע שלי בצורה הכי טובה ואיכותית שיש.
#
# הבנתי גם שלמרות שיש פקודות שמגיעות לאותה מטרה יש כאלו אשר פועלות בצורה טובה יותר תלוי במאגר הנתונים שעליו מריצים את הפקודות.
#
# לסיכום העבודה הייתה מאתגרת ומעניינת, הרגשתי שלמדתי דרכה הרבה דברים חדשים.

# %% [markdown]
# # **שאלת מבחן:**

# %% [markdown]
# <div dir="rtl">
#
#
#
# עשייה על שלב הknn בחילוק שונה,
# במקום לחלק 20 לבדיקה ו80 לאימון, לעשות 30 לבדיקה ו70 לאימון ואז השוואה

# %%
# הכנה של הערכים ללימוד המכונה
x = df.drop(['residual sugar'],axis=1).to_numpy()
x.shape
# Out:
# (1143, 11)

# %%
# הכנה של ערך העמודה האופקית, אשר אני רוצה למדוד, שזהו איכות היין
y = df['quality'].to_numpy()
y.shape
# Out:
# (1143,)

# %%
#שליחת הנתונים לאימון ובדיקה
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,\
                                               shuffle=True,random_state=100)

print("train: ",X_train.shape,y_train.shape)

print("test: ",X_test.shape,y_test.shape)
# Out:
# train:  (800, 11) (800,)
# test:  (343, 11) (343,)

# %%
# אפשרות שניה לנרמול בשיטה סטנדרטית
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
pipe = Pipeline([
        ('scale', StandardScaler()),
        # הוא הופך את הנתונים כך שהממוצע שלהם יהיה 0 וסטיית התקן תהיה 1.
        ('knn', KNeighborsRegressor())
        # העברת הנתונים למודל לאחר נרמול
        ])


param_grid = {
    'knn__n_neighbors' :[k for k in range(1,700,20)]
}

# %%
knn_clf = GridSearchCV(pipe, param_grid=param_grid, cv=5, verbose=1)

knn_clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 35 candidates, totalling 175 fits
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 641, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 641, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 641, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 641, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 641, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 661, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 661, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 661, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 661, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 661, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 681, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 681, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 681, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 681, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:960: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 949, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/metrics/_scorer.py", line 472, in __call__
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/pipeline.py", line 1199, in score
#     return self.steps[-1][1].score(Xt, y, **score_params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 662, in score
#     y_pred = self.predict(X)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_regression.py", line 243, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/neighbors/_base.py", line 854, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples_fit, but n_neighbors = 681, n_samples_fit = 640, n_samples = 160
#
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.82659977 0.77942828 0.73927621 0.70873776 0.68128119 0.6502286
#  0.61913702 0.5912033  0.56609566 0.54070176 0.51799284 0.49548998
#  0.47229078 0.45186173 0.43086069 0.41000253 0.38865189 0.3670957
#  0.3454445  0.32523707 0.30402771 0.2830949  0.26022225 0.23683005
#  0.21251173 0.18609304 0.1591742  0.13241553 0.10568788 0.07810273
#  0.04698031 0.01307866        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('knn', KNeighborsRegressor())]),
#              param_grid={'knn__n_neighbors': [1, 21, 41, 61, 81, 101, 121, 141,
#                                               161, 181, 201, 221, 241, 261, 281,
#                                               301, 321, 341, 361, 381, 401, 421,
#                                               441, 461, 481, 501, 521, 541, 561,
#                                               581, ...]},
#              verbose=1)

# %%
# מוצא את ערך החיזוי הכי קרוב למציאות ומדפיס אותו, ערך חיזוי של 1 אומר שזה חזה במדוייק
best_k = knn_clf.best_params_['knn__n_neighbors']
print("The best k is: ",best_k)

# מבטיח שהערך שמצאנו בשורת הקוד הקודמת יהיה במודל החדש הנשמר במשתנה
#Knn1
Knn1 = KNeighborsRegressor(n_neighbors=best_k)
Knn1.fit(X_train,y_train)
# Out:
# The best k is:  1
# KNeighborsRegressor(n_neighbors=1)

# %%
cv_results = pd.DataFrame(knn_clf.cv_results_)
print(cv_results[['param_knn__n_neighbors','mean_test_score','rank_test_score']].sort_values('rank_test_score'))
# Out:
#     param_knn__n_neighbors  mean_test_score  rank_test_score
# 0                        1         0.826600                1
# 1                       21         0.779428                2
# 2                       41         0.739276                3
# 3                       61         0.708738                4
# 4                       81         0.681281                5
# 5                      101         0.650229                6
# 6                      121         0.619137                7
# 7                      141         0.591203                8
# 8                      161         0.566096                9
# 9                      181         0.540702               10
# 10                     201         0.517993               11
# 11                     221         0.495490               12
# 12                     241         0.472291               13
# 13                     261         0.451862               14
# 14                     281         0.430861               15
# 15                     301         0.410003               16
# 16                     321         0.388652               17
# 17                     341         0.367096               18
# 18                     361         0.345445               19
# 19                     381         0.325237               20
# 20                     401         0.304028               21
# 21                     421         0.283095               22
# 22                     441         0.260222               23
# 23                     461         0.236830               24
# 24                     481         0.212512               25
# 25                     501         0.186093               26
# 26                     521         0.159174               27
# 27                     541         0.132416               28
# 28                     561         0.105688               29
# 29                     581         0.078103               30
# 30                     601         0.046980               31
# 31                     621         0.013079               32
# 32                     641              NaN               33
# 33                     661              NaN               33
# 34                     681              NaN               33

# %%
# מקבל את הנתונים לבדיקה ומנסה לחזות אותם, אני שומרת את החיזוי בתור משתנה בשביל להציג לאחר מכן
y_pred = Knn1.predict(X_test)
y_pred.shape
# Out:
# (343,)

# %%
#הגדרה של גודל התצוגה
fig,ax = plt.subplots(figsize=(10,10))
# להראות את התצוגה של הערכים שחיזינו מול הערכים האמיתיים
confusion_matrix= ConfusionMatrixDisplay.from_predictions(y_test,y_pred,ax=ax)
# מדפיס את הקשר הלינארי בין ערכים שונים
print(classification_report(y_true=y_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.67      0.36      0.47        11
#            5       0.92      0.97      0.94       148
#            6       0.93      0.94      0.94       145
#            7       0.91      0.81      0.86        37
#            8       1.00      1.00      1.00         2
#
#     accuracy                           0.92       343
#    macro avg       0.89      0.82      0.84       343
# weighted avg       0.92      0.92      0.92       343

# %%
knn3 = KNeighborsRegressor(n_neighbors=1)
knn3.fit(x,y)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
print(accuracy_score(y_true=y_test, y_pred = y_pred)*100)
# Out:
# 92.12827988338192

# %%
knn3.predict([[7.9,0.52,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0.62,10.2]])
# Out:
# array([8.])

# %%
knn3.predict([[7.9,0.52,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0.62,8]])
# Out:
# array([5.])

# %%
knn3.predict([[7.9,1.5,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0.62,10.2]])
# Out:
# array([8.])

# %%
knn3.predict([[7.9,0.52,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0,10.2]])
# Out:
# array([8.])

# %%
knn3.predict([[7.9,1.5,0.25,2.2,0.079,13.0,37.0,0.9978,3.31,0,8]])
# Out:
# array([5.])

# %%
knn3.predict([[7.1,0.39,0.09,1.9,0.07,7.0,21.0,0.9955,3.2,0.55,9.5]])
# Out:
# array([6.])

# %%
knn3.predict([[11.2,0.28,0.56,1.9,0.075,17.0,60.0,0.9980,3.16,0.58,9.8]])
# Out:
# array([6.])

# %% [markdown]
# <div dir="rtl">
#
# השוואה בין ה accuracy score:
# בראשון הדיוק היה 93% לעומת השני אשר היה 92%
#
#
# אין שינוי בערכי החיזוי שבדקתי בסוף השלבים
#
# יש שינוי ב pd.DataFrame,
# אפשר לראות שבשלושת השורות האחרונות יש ערכים חסרים כנראה מכיוון שהמודל צריך עוד נתונים בשביל בדיקה בכמות גבוהה יותר
